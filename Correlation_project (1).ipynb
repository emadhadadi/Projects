# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None



df = pd.read_csv(r'movies.csv')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.shape
# Out:
# (7668, 15)

# %%
df1=df.isnull().sum()
print(df1)
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
print("sum of null values: ",sum(df1))
# Out:
# sum of null values:  2473

# %%
# remove null values
df.dropna(inplace = True)

# %%
print(df.isnull().sum())
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# change data types
df['gross']=df['gross'].astype('int64')
df['budget']=df['budget'].astype('int64')

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
import datetime
df['year']=df['year'].astype('datetime64[ns]')

# %%
#pd.set_option('display.max_rows',None)

# %%
df.sort_values(by=['gross'],inplace=False,ascending=False).head()
# Out:
#                                             name rating   genre  \
# 5445                                      Avatar  PG-13  Action
# 7445                           Avengers: Endgame  PG-13  Action
# 3045                                     Titanic  PG-13   Drama
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action
# 7244                      Avengers: Infinity War  PG-13  Action
#
#                               year                           released  score  \
# 5445 1970-01-01 00:00:00.000002009  December 18, 2009 (United States)    7.8
# 7445 1970-01-01 00:00:00.000002019     April 26, 2019 (United States)    8.4
# 3045 1970-01-01 00:00:00.000001997  December 19, 1997 (United States)    7.8
# 6663 1970-01-01 00:00:00.000002015  December 18, 2015 (United States)    7.8
# 7244 1970-01-01 00:00:00.000002018     April 27, 2018 (United States)    8.4
#
#           votes       director              writer               star  \
# ...

# %%
# scatter plot with (budget vs gross)

plt.scatter(x=df['budget'],y=df['gross'])
plt.title("Budget vs Gross Earning")
plt.xlabel('Gross Earning')
plt.ylabel('Budget for film')
plt.show()

# %%
# regrission plot
sns.regplot(x='budget',y='gross',data=df,scatter_kws={"color":"green"},line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
df.corr(method='pearson') # pearson method is default method
# Out:
#             score     votes    budget     gross   runtime
# score    1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
df.corr(method='kendall')
# Out:
#             score     votes    budget     gross   runtime
# score    1.000000  0.350185 -0.006406  0.124943  0.292254
# votes    0.350185  1.000000  0.346274  0.553625  0.205344
# budget  -0.006406  0.346274  1.000000  0.512057  0.231278
# gross    0.124943  0.553625  0.512057  1.000000  0.176979
# runtime  0.292254  0.205344  0.231278  0.176979  1.000000

# %%
df.corr(method='spearman')
# Out:
#             score     votes    budget     gross   runtime
# score    1.000000  0.495409 -0.009971  0.183192  0.412155
# votes    0.495409  1.000000  0.493461  0.745793  0.300621
# budget  -0.009971  0.493461  1.000000  0.692958  0.330794
# gross    0.183192  0.745793  0.692958  1.000000  0.257400
# runtime  0.412155  0.300621  0.330794  0.257400  1.000000

# %%
df.head()
# Out:
#                                              name rating      genre  \
# 0                                     The Shining      R      Drama
# 1                                 The Blue Lagoon      R  Adventure
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action
# 3                                       Airplane!     PG     Comedy
# 4                                      Caddyshack      R     Comedy
#
#                            year                       released  score  \
# 0 1970-01-01 00:00:00.000001980  June 13, 1980 (United States)    8.4
# 1 1970-01-01 00:00:00.000001980   July 2, 1980 (United States)    5.8
# 2 1970-01-01 00:00:00.000001980  June 20, 1980 (United States)    8.7
# 3 1970-01-01 00:00:00.000001980   July 2, 1980 (United States)    7.7
# 4 1970-01-01 00:00:00.000001980  July 25, 1980 (United States)    7.3
#
#        votes         director                   writer            star  \
# ...

# %%
correlation_matrix = df.corr()

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
df.head()
# Out:
#                                              name rating      genre  \
# 0                                     The Shining      R      Drama
# 1                                 The Blue Lagoon      R  Adventure
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action
# 3                                       Airplane!     PG     Comedy
# 4                                      Caddyshack      R     Comedy
#
#                            year                       released  score  \
# 0 1970-01-01 00:00:00.000001980  June 13, 1980 (United States)    8.4
# 1 1970-01-01 00:00:00.000001980   July 2, 1980 (United States)    5.8
# 2 1970-01-01 00:00:00.000001980  June 20, 1980 (United States)    8.7
# 3 1970-01-01 00:00:00.000001980   July 2, 1980 (United States)    7.7
# 4 1970-01-01 00:00:00.000001980  July 25, 1980 (United States)    7.3
#
#        votes         director                   writer            star  \
# ...

# %%
df_num =df
df_num=df_num.apply(lambda x: x.factorize()[0]).corr(method='pearson')

df_num
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000  0.169808  0.028413  0.965461  0.966086 -0.020083
# rating    0.169808  1.000000 -0.116507  0.179456  0.171063  0.036114
# genre     0.028413 -0.116507  1.000000  0.031765  0.031251 -0.027402
# year      0.965461  0.179456  0.031765  1.000000  0.996490 -0.014594
# released  0.966086  0.171063  0.031251  0.996490  1.000000 -0.019486
# score    -0.020083  0.036114 -0.027402 -0.014594 -0.019486  1.000000
# votes     0.297305  0.097619 -0.009983  0.323916  0.313254 -0.041981
# director  0.725411  0.096014  0.036671  0.747785  0.750825 -0.006583
# writer    0.791872  0.128909  0.033975  0.812386  0.809858 -0.021538
# star      0.695124  0.115694  0.045497  0.719373  0.720076  0.015108
# country   0.098110 -0.004547 -0.003314  0.095073  0.096807  0.016567
# budget    0.288955  0.203698  0.020893  0.319135  0.309616 -0.005493
# gross     0.967925  0.172703  0.032033  0.996371  0.998490 -0.015744
# ...

# %%
correlation_matrix = df_num.corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
correlation_mat=df_num.corr()
pairs=correlation_mat.unstack()
sorted_pairs=pairs.sort_values()
sorted_pairs
# Out:
# genre     rating     -0.399285
# rating    genre      -0.399285
# score     year       -0.397640
# year      score      -0.397640
# released  score      -0.397430
# score     released   -0.397430
#           name       -0.395454
# name      score      -0.395454
# score     gross      -0.394120
# gross     score      -0.394120
# runtime   director   -0.385553
# director  runtime    -0.385553
# score     writer     -0.384614
# writer    score      -0.384614
# score     director   -0.352358
# director  score      -0.352358
# runtime   company    -0.343972
# company   runtime    -0.343972
# writer    runtime    -0.341349
# runtime   writer     -0.341349
# star      score      -0.340788
# score     star       -0.340788
# star      runtime    -0.334939
# runtime   star       -0.334939
# votes     score      -0.329231
# score     votes      -0.329231
# runtime   gross      -0.324870
# gross     runtime    -0.324870
# released  runtime    -0.323246
# runtime   released   -0.323246
# ...

# %%
high_correlation = sorted_pairs[(sorted_pairs > 0.5)]
high_correlation
# Out:
# budget    votes       0.529528
# votes     budget      0.529528
# star      company     0.758131
# company   star        0.758131
# year      company     0.761795
# company   year        0.761795
# released  company     0.768149
# company   released    0.768149
# gross     company     0.769063
# company   gross       0.769063
# writer    company     0.769754
# company   writer      0.769754
#           name        0.770061
# name      company     0.770061
# director  company     0.789198
# company   director    0.789198
# star      writer      0.911674
# writer    star        0.911674
# director  star        0.917628
# star      director    0.917628
#           name        0.922383
# name      star        0.922383
# star      year        0.923899
# year      star        0.923899
# released  star        0.925298
# star      released    0.925298
# gross     star        0.925920
# star      gross       0.925920
# director  name        0.939555
# name      director    0.939555
# ...

# %%
# Votes and budget have the highest correlation to gross earnings
